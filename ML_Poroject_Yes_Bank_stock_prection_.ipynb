# %% [markdown]
# # **Project Name**    - Yes Bank Stock Closing Price Prediction

# %% [markdown]
# ##### **Project Type**    - EDA/Regression/Classification/Unsupervised
# ##### **Contribution**    - Individual/Team

# %% [markdown]
# # **Project Summary -**

# %% [markdown]
# Yes Bank is one of the well-known private sector banks in India. In recent years, the bank attracted significant attention due to financial and governance issues, which had a major impact on its stock prices. As stock prices are influenced by multiple factors and market conditions, predicting future stock movements is a challenging task. This project aims to analyze the historical stock price data of Yes Bank and build a machine learning model to predict its monthly closing stock price.
#
# The dataset used in this project contains historical monthly stock price information of Yes Bank from its inception. It includes important stock market variables such as Open Price, High Price, Low Price, and Close Price. The Close Price is considered the target variable, while the remaining variables are used as independent features for prediction. Since stock prices generally follow patterns based on historical performance, machine learning techniques can be applied to identify these relationships and make future predictions.
#
# The project began with data understanding and exploratory data analysis (EDA). The dataset was examined to understand its structure, data types, missing values, and overall quality. Various visualizations were created to identify trends, distributions, correlations, and stock price behavior over time. The analysis revealed strong relationships between the Open, High, Low, and Close prices. It also highlighted significant fluctuations in stock prices during certain periods, reflecting the impact of market conditions and company-specific events.
#
# After the exploratory analysis, data preprocessing techniques were applied to prepare the dataset for machine learning. The Date column was converted into a suitable format, and additional time-based features were extracted where necessary. Since the dataset was relatively clean, only minimal preprocessing was required. The data was then divided into training and testing sets to evaluate the model's ability to generalize to unseen data.
#
# Several regression-based machine learning algorithms can be used for this problem, such as Linear Regression, Decision Tree Regressor, and Random Forest Regressor. These models help estimate the closing stock price based on historical stock market information. Model performance is evaluated using regression metrics such as Mean Absolute Error (MAE), Root Mean Squared Error (RMSE), and R-squared Score (R²). The best-performing model can then be selected based on these evaluation metrics.
#
# The insights generated from this project can be valuable for investors, financial analysts, and stakeholders who want to understand stock market trends and make informed decisions. While historical stock data provides useful information for forecasting, external factors such as economic conditions, company announcements, and market sentiment can also influence stock prices. Therefore, future improvements may include incorporating additional financial indicators and real-time market data to enhance prediction accuracy.
#
# Overall, this project demonstrates the application of machine learning techniques in financial forecasting and highlights how data-driven approaches can support better investment and business decisions.

# %% [markdown]
# # **GitHub Link -**

# %% [markdown]
# https://github.com/Jorawarsingh25?tab=repositories

# %% [markdown]
# # **Problem Statement**

# %% [markdown]
# The objective of this project is to predict the monthly closing stock price of Yes Bank using historical stock price data. The dataset contains Open, High, Low, and Close prices for each month. Since stock prices are influenced by market conditions and financial events, accurate prediction can help investors and analysts make informed decisions. The goal is to build and evaluate machine learning regression models that can forecast the closing stock price based on historical trends and patterns.

# %% [markdown]
# # **General Guidelines** : -

# %% [markdown]
# 1.   Well-structured, formatted, and commented code is required.
# 2.   Exception Handling, Production Grade Code & Deployment Ready Code will be a plus. Those students will be awarded some additional credits.
#
#      The additional credits will have advantages over other students during Star Student selection.
#
#              [ Note: - Deployment Ready Code is defined as, the whole .ipynb notebook should be executable in one go
#                        without a single error logged. ]
#
# 3.   Each and every logic should have proper comments.
# 4. You may add as many number of charts you want. Make Sure for each and every chart the following format should be answered.
#
#
# ```
# # Chart visualization code
# ```
#
#
# *   Why did you pick the specific chart?
# *   What is/are the insight(s) found from the chart?
# * Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.
#
# 5. You have to create at least 15 logical & meaningful charts having important insights.
#
#
# [ Hints : - Do the Vizualization in  a structured way while following "UBM" Rule.
#
# U - Univariate Analysis,
#
# B - Bivariate Analysis (Numerical - Categorical, Numerical - Numerical, Categorical - Categorical)
#
# M - Multivariate Analysis
#  ]
#
#
#
#
#
# 6. You may add more ml algorithms for model creation. Make sure for each and every algorithm, the following format should be answered.
#
#
# *   Explain the ML Model used and it's performance using Evaluation metric Score Chart.
#
#
# *   Cross- Validation & Hyperparameter Tuning
#
# *   Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.
#
# *   Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# # ***Let's Begin !***

# %% [markdown]
# ## ***1. Know Your Data***

# %% [markdown]
# ### Import Libraries

# %%
# Import Libraries

# Data Manipulation
import pandas as pd
import numpy as np

# Data Visualization
import matplotlib.pyplot as plt
import seaborn as sns

# Machine Learning
from sklearn.model_selection import train_test_split
from sklearn.model_selection import cross_val_score
from sklearn.model_selection import GridSearchCV

# Feature Scaling
from sklearn.preprocessing import StandardScaler

# Regression Models
from sklearn.linear_model import LinearRegression
from sklearn.tree import DecisionTreeRegressor
from sklearn.ensemble import RandomForestRegressor

# Evaluation Metrics
from sklearn.metrics import mean_absolute_error
from sklearn.metrics import mean_squared_error
from sklearn.metrics import r2_score

# Ignore Warnings
import warnings
warnings.filterwarnings('ignore')

# %% [markdown]
# ### Dataset Loading

# %%
# Load Dataset

df = pd.read_csv('/content/data_YesBank_StockPrices.csv')

# Display first 5 rows
df.head()

# %% [markdown]
# ### Dataset First View

# %%
# Display first few rows of the dataset

df.head()

# %% [markdown]
# ### Dataset Rows & Columns count

# %%
# Check number of rows and columns

print("Number of Rows :", df.shape[0])
print("Number of Columns :", df.shape[1])

# %% [markdown]
# ### Dataset Information

# %%
# Dataset Information

df.info()

# %% [markdown]
# #### Duplicate Values

# %%
# Check duplicate records

duplicate_values = df.duplicated().sum()

print("Duplicate Values :", duplicate_values)

# %% [markdown]
# #### Missing Values/Null Values

# %%
# Check missing values

df.isnull().sum()

# %%
# Visualizing Missing Values

plt.figure(figsize=(8,5))
sns.heatmap(df.isnull(), cbar=False, cmap='viridis')

plt.title('Missing Values Heatmap')
plt.show()

# %% [markdown]
# ### What did you know about your dataset?

# %% [markdown]
# The dataset contains historical monthly stock price data of Yes Bank, including Date, Open, High, Low, and Close prices. It consists of both time-based and numerical features, where Close Price is the target variable for prediction. The dataset is clean, with no missing values or duplicate records, making it suitable for machine learning modeling and stock price forecasting. The strong relationship among the stock price variables suggests that they can be useful predictors for estimating the closing stock price.

# %% [markdown]
# ## ***2. Understanding Your Variables***

# %%
# Display all columns in the dataset

df.columns

# %%
# Statistical summary of numerical columns

df.describe()

# %% [markdown]
# ### Variables Description

# %% [markdown]
# Date – Represents the month and year of the stock price record.
#
# Open – Opening stock price of Yes Bank at the beginning of the month.
#
# High – Highest stock price reached during the month.
#
# Low – Lowest stock price reached during the month.
#
# Close – Closing stock price at the end of the month. This is the target variable that will be predicted using machine learning models.

# %% [markdown]
# ### Check Unique Values for each variable.

# %%
# Check unique values count for each column

for col in df.columns:
    print(f"{col} : {df[col].nunique()}")

# %% [markdown]
# ## 3. ***Data Wrangling***

# %% [markdown]
# ### Data Wrangling Code

# %%
# Write your code to make your dataset analysis ready.

# Convert Date column into datetime format
df['Date'] = pd.to_datetime(df['Date'], format='%b-%y')

# Extract Year and Month from Date
df['Year'] = df['Date'].dt.year
df['Month'] = df['Date'].dt.month

# Check duplicate values
df.drop_duplicates(inplace=True)

# Check missing values
print(df.isnull().sum())

# Display first few rows
df.head()

# %% [markdown]
# ### What all manipulations have you done and insights you found?

# %% [markdown]
# The Date column was converted into datetime format, and new Year and Month features were created for better analysis. Duplicate records were removed to maintain data quality, and missing values were checked to ensure data completeness. These preprocessing steps made the dataset suitable for machine learning modeling and helped extract useful time-based information from the stock price data.

# %% [markdown]
# ## ***4. Data Vizualization, Storytelling & Experimenting with charts : Understand the relationships between variables***

# %% [markdown]
# #### Chart - 1

# %%
# Distribution Plot of Open Price

plt.figure(figsize=(8,5))
sns.histplot(df['Open'], kde=True)
plt.title('Distribution of Open Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# The histogram helps understand the distribution and frequency of opening stock prices.Answer Here.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows how opening prices are distributed and whether the data is skewed or normally distributed.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the distribution of opening prices helps identify common price ranges and unusual values. Extreme variations may indicate periods of market uncertainty and increased investment risk.

# %% [markdown]
# #### Chart - 2

# %%
# Distribution Plot of High Price

plt.figure(figsize=(8,5))
sns.histplot(df['High'], kde=True)
plt.title('Distribution of High Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze the distribution of the highest stock prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the frequency and spread of high prices.Answer Here

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps identify stock price trends and market movements.

# %% [markdown]
# #### Chart - 3

# %%
# Distribution Plot of Low Price

plt.figure(figsize=(8,5))
sns.histplot(df['Low'], kde=True)
plt.title('Distribution of Low Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand the distribution of the lowest stock prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart shows the variation in minimum stock prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps assess downside risk and price fluctuations.

# %% [markdown]
# #### Chart - 4

# %%
# Distribution Plot of Close Price

plt.figure(figsize=(8,5))
sns.histplot(df['Close'], kde=True)
plt.title('Distribution of Close Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand the distribution of the target variable.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The closing prices show variation over time and indicate market trends.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, understanding the target variable helps improve model selection and prediction accuracy.

# %% [markdown]
# #### Chart - 5

# %%
# Box Plot of Stock Prices

plt.figure(figsize=(10,5))
sns.boxplot(data=df[['Open','High','Low','Close']])
plt.title('Box Plot of Stock Prices')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To identify outliers and compare stock price distributions.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The chart highlights extreme values and stock price variability.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, identifying outliers helps improve model reliability and data quality.

# %% [markdown]
# #### Chart - 6

# %%
# Scatter Plot between Open and Close Price

plt.figure(figsize=(8,5))
sns.scatterplot(x='Open', y='Close', data=df)
plt.title('Open Price vs Close Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To examine the relationship between opening and closing prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A strong positive relationship exists between Open and Close prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it indicates that opening price is an important predictor of closing price.

# %% [markdown]
# #### Chart - 7

# %%
# Scatter Plot between High and Close Price

plt.figure(figsize=(8,5))
sns.scatterplot(x='High', y='Close', data=df)
plt.title('High Price vs Close Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze the relationship between high and closing prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A strong positive correlation exists between High and Close prices.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps improve stock price prediction models.

# %% [markdown]
# #### Chart - 8

# %%
# Scatter Plot between Low and Close Price

plt.figure(figsize=(8,5))
sns.scatterplot(x='Low', y='Close', data=df)
plt.title('Low Price vs Close Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze the effect of low prices on closing prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The variables show a strong positive relationship.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, low price information can improve forecasting accuracy.

# %% [markdown]
# #### Chart - 9

# %%
# Correlation Heatmap

plt.figure(figsize=(8,6))
sns.heatmap(df[['Open','High','Low','Close']].corr(),
            annot=True,
            cmap='coolwarm')
plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To understand relationships among numerical variables.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# All stock price variables are highly correlated.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, highly correlated features can effectively support prediction models.

# %% [markdown]
# #### Chart - 10

# %%
# Scatter Plot between Open and High Price

plt.figure(figsize=(8,5))
sns.scatterplot(x='Open', y='High', data=df)
plt.title('Open Price vs High Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To analyze the relationship between opening and highest prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Both variables move closely together.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps understand stock movement patterns.

# %% [markdown]
# #### Chart - 11

# %%
# Scatter Plot between Open and Low Price

plt.figure(figsize=(8,5))
sns.scatterplot(x='Open', y='Low', data=df)
plt.title('Open Price vs Low Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To examine the relationship between opening and lowest prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# A positive relationship exists between both variables.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps understand price fluctuations within a trading period.

# %% [markdown]
# #### Chart - 12

# %%
# Scatter Plot between High and Low Price

plt.figure(figsize=(8,5))
sns.scatterplot(x='High', y='Low', data=df)
plt.title('High Price vs Low Price')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To compare the highest and lowest stock prices.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The variables show a strong positive correlation.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it provides insight into stock price volatility.

# %% [markdown]
# #### Chart - 13

# %%
# Pair Plot

sns.pairplot(df[['Open','High','Low','Close']])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# To visualize multiple variable relationships simultaneously.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# Strong positive relationships exist among all stock price variables.

# %% [markdown]
# ##### 3. Will the gained insights help creating a positive business impact?
# Are there any insights that lead to negative growth? Justify with specific reason.

# %% [markdown]
# Yes, it helps identify important features for model development.

# %% [markdown]
# #### Chart - 14 - Correlation Heatmap

# %%
# Correlation Heatmap

plt.figure(figsize=(8,6))
sns.heatmap(df[['Open','High','Low','Close']].corr(),
            annot=True,
            cmap='coolwarm',
            fmt='.2f')

plt.title('Correlation Heatmap')
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A correlation heatmap was chosen to understand the strength and direction of relationships between numerical variables in the dataset.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The heatmap shows a strong positive correlation among Open, High, Low, and Close prices. This indicates that changes in one stock price variable are closely associated with changes in the others.

# %% [markdown]
# #### Chart - 15 - Pair Plot

# %%
# Pair Plot of Numerical Variables

sns.pairplot(df[['Open','High','Low','Close']])
plt.show()

# %% [markdown]
# ##### 1. Why did you pick the specific chart?

# %% [markdown]
# A pair plot was chosen because it allows visualization of relationships between multiple numerical variables simultaneously. It helps identify correlations, trends, and data distributions in a single view.

# %% [markdown]
# ##### 2. What is/are the insight(s) found from the chart?

# %% [markdown]
# The pair plot shows strong positive relationships among Open, High, Low, and Close prices. As one stock price variable increases, the others tend to increase as well. The diagonal plots also show the distribution of each variable.

# %% [markdown]
# ## ***5. Hypothesis Testing***

# %% [markdown]
# ### Based on your chart experiments, define three hypothetical statements from the dataset. In the next three questions, perform hypothesis testing to obtain final conclusion about the statements through your code and statistical testing.

# %% [markdown]
# After analyzing the visualizations and relationships between stock price variables, the following hypotheses were formulated:
#
# Hypothesis 1: There is a significant relationship between the Open Price and Close Price of Yes Bank stock.
#
# Hypothesis 2: There is a significant relationship between the High Price and Close Price of Yes Bank stock.
#
# Hypothesis 3: There is a significant relationship between the Low Price and Close Price of Yes Bank stock.
#
# These hypotheses were derived from the scatter plots, correlation heatmap, and pair plot, which indicated strong positive relationships among the stock price variables. Statistical hypothesis testing is performed in the following sections to verify whether these relationships are statistically significant.

# %% [markdown]
# ### Hypothetical Statement - 1

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis (H₀): There is no significant relationship between the Open Price and Close Price of Yes Bank stock.
#
# Alternate Hypothesis (H₁): There is a significant relationship between the Open Price and Close Price of Yes Bank stock.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr

corr, p_value = pearsonr(df['Open'], df['Close'])

print("Correlation Coefficient:", corr)
print("P-value:", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Pearson Correlation Test was used to calculate the correlation coefficient and p-value between Open Price and Close Price.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The Pearson Correlation Test was chosen because both Open Price and Close Price are continuous numerical variables. This test helps measure the strength and direction of the linear relationship between the two variables and determines whether the relationship is statistically significant.

# %% [markdown]
# ### Hypothetical Statement - 2

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis (H₀): There is no significant relationship between the High Price and Close Price of Yes Bank stock.
#
# Alternate Hypothesis (H₁): There is a significant relationship between the High Price and Close Price of Yes Bank stock.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr

corr, p_value = pearsonr(df['High'], df['Close'])

print("Correlation Coefficient:", corr)
print("P-value:", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Pearson Correlation Test was used to determine the relationship between High Price and Close Price.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The Pearson Correlation Test is suitable because both High Price and Close Price are continuous numerical variables. It helps measure the strength of the linear relationship between them and determines whether the relationship is statistically significant.

# %% [markdown]
# ### Hypothetical Statement - 3

# %% [markdown]
# #### 1. State Your research hypothesis as a null hypothesis and alternate hypothesis.

# %% [markdown]
# Null Hypothesis (H₀): There is no significant relationship between the Low Price and Close Price of Yes Bank stock.
#
# Alternate Hypothesis (H₁): There is a significant relationship between the Low Price and Close Price of Yes Bank stock.

# %% [markdown]
# #### 2. Perform an appropriate statistical test.

# %%
# Perform Statistical Test to obtain P-Value
from scipy.stats import pearsonr

corr, p_value = pearsonr(df['Low'], df['Close'])

print("Correlation Coefficient:", corr)
print("P-value:", p_value)

# %% [markdown]
# ##### Which statistical test have you done to obtain P-Value?

# %% [markdown]
# Pearson Correlation Test was used to calculate the correlation coefficient and p-value between Low Price and Close Price.

# %% [markdown]
# ##### Why did you choose the specific statistical test?

# %% [markdown]
# The Pearson Correlation Test was chosen because both Low Price and Close Price are continuous numerical variables. This test helps determine the strength and direction of the linear relationship between these variables and verifies whether the relationship is statistically significant.

# %% [markdown]
# ## ***6. Feature Engineering & Data Pre-processing***

# %% [markdown]
# ### 1. Handling Missing Values

# %%
# Handling Missing Values & Missing Value Imputation

df.isnull().sum()

# %% [markdown]
# #### What all missing value imputation techniques have you used and why did you use those techniques?

# %% [markdown]
# The dataset did not contain any missing values. Therefore, no missing value imputation technique was required. A missing value check was performed to ensure data quality and completeness before proceeding with analysis and model building.

# %% [markdown]
# ### 2. Handling Outliers

# %%
# Handling Outliers & Outlier treatments
# Detecting outliers using IQR

for col in ['Open','High','Low','Close']:

    Q1 = df[col].quantile(0.25)
    Q3 = df[col].quantile(0.75)

    IQR = Q3 - Q1

    lower_bound = Q1 - 1.5 * IQR
    upper_bound = Q3 + 1.5 * IQR

    outliers = df[(df[col] < lower_bound) | (df[col] > upper_bound)]

    print(col, ":", len(outliers))

# %% [markdown]
# ##### What all outlier treatment techniques have you used and why did you use those techniques?

# %% [markdown]
# Outliers were identified using the Interquartile Range (IQR) method through box plots and statistical analysis. Since stock market data naturally contains price fluctuations and extreme values that represent real market behavior, the outliers were not removed. Retaining these values helps preserve important information and improves the model's ability to learn actual market trends.

# %% [markdown]
# ### 3. Categorical Encoding

# %%
# Encode your categorical columns
#No categorical variables were present in the dataset. Therefore, no categorical encoding technique was required.

# %% [markdown]
# #### What all categorical encoding techniques have you used & why did you use those techniques?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Textual Data Preprocessing
# (It's mandatory for textual dataset i.e., NLP, Sentiment Analysis, Text Clustering etc.)

# %% [markdown]
# #### 1. Expand Contraction

# %%
# Expand Contraction
#Not Applicable. The dataset does not contain textual data.

# %% [markdown]
# #### 2. Lower Casing

# %%
# Lower Casing
#Not Applicable. The dataset contains numerical stock price data only.

# %% [markdown]
# #### 3. Removing Punctuations

# %%
# Remove Punctuations
#Not Applicable. No text preprocessing was required.

# %% [markdown]
# #### 4. Removing URLs & Removing words and digits contain digits.

# %%
# Remove URLs & Remove words and digits contain digits

# %% [markdown]
# #### 5. Removing Stopwords & Removing White spaces

# %%
# Remove Stopwords
#Not Applicable. The dataset does not contain text features.

# %%
# Remove White
# N/A

# %% [markdown]
# #### 6. Rephrase Text

# %%
# Rephrase Text
# N/A

# %% [markdown]
# #### 7. Tokenization

# %%
# Tokenization
#Not Applicable. Tokenization is used in NLP tasks and is not relevant to this project.

# %% [markdown]
# #### 8. Text Normalization

# %%
# Normalizing Text (i.e., Stemming, Lemmatization etc.)
#Not Applicable. No text normalization techniques were required because the dataset contains numerical data.

# %% [markdown]
# ##### Which text normalization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# #### 9. Part of speech tagging

# %%
# POS Taging
# Not Applicable. POS Tagging is used for textual data analysis.

# %% [markdown]
# #### 10. Text Vectorization

# %%
# Vectorizing Text
# Not Applicable. Text vectorization techniques such as TF-IDF and Count Vectorizer were not required because the dataset contains no text data.

# %% [markdown]
# ##### Which text vectorization technique have you used and why?

# %% [markdown]
# Answer Here.

# %% [markdown]
# ### 4. Feature Manipulation & Selection

# %% [markdown]
# #### 1. Feature Manipulation

# %%
# Manipulate Features to minimize feature correlation and create new features
# Creating new features from existing stock prices

df['Price_Range'] = df['High'] - df['Low']

df['Price_Change'] = df['Close'] - df['Open']

# Display dataset
df.head()

# %% [markdown]
# #### 2. Feature Selection

# %%
# Select your features wisely to avoid overfitting
# Selecting important features

X = df[['Open', 'High', 'Low']]
y = df['Close']

print("Selected Features:")
print(X.columns)

# %% [markdown]
# ##### What all feature selection methods have you used  and why?

# %% [markdown]
# Correlation analysis was used as the primary feature selection method. A correlation heatmap was created to understand the relationship between independent variables and the target variable (Close Price). Features that showed a strong relationship with the target variable were selected for model building. This approach helps reduce irrelevant information and minimizes the risk of overfitting.

# %% [markdown]
# ##### Which all features you found important and why?

# %% [markdown]
# The features Open, High, and Low were found to be the most important because they showed a strong positive correlation with the Close Price, which is the target variable. These features capture the daily stock price movement and contain valuable information for predicting the closing stock price. Therefore, they were selected as input variables for the machine learning models.

# %% [markdown]
# ### 5. Data Transformation

# %% [markdown]
# #### Do you think that your data needs to be transformed? If yes, which transformation have you used. Explain Why?

# %%
# Transform Your data
# Defining features and target variable

X = df[['Open', 'High', 'Low']]
y = df['Close']

# %% [markdown]
# ### 6. Data Scaling

# %%
# Scaling your data
from sklearn.preprocessing import StandardScaler

# Initialize scaler
scaler = StandardScaler()

# Scale features
X_scaled = scaler.fit_transform(X)

# Display scaled data
X_scaled[:5]

# %% [markdown]
# ##### Which method have you used to scale you data and why?

# %% [markdown]
# StandardScaler was used because it transforms features to have a mean of 0 and a standard deviation of 1, helping machine learning models learn more effectively.

# %% [markdown]
# ### 7. Dimesionality Reduction

# %% [markdown]
# ##### Do you think that dimensionality reduction is needed? Explain Why?

# %% [markdown]
# No. The dataset contains only a few highly relevant features, so dimensionality reduction is not required.

# %%
# Dimensionality Reduction was not applied

print("Dimensionality Reduction Not Required")

# %% [markdown]
# ##### Which dimensionality reduction technique have you used and why? (If dimensionality reduction done on dataset.)

# %% [markdown]
# No dimensionality reduction technique was applied because reducing features could result in the loss of important information needed for stock price prediction.

# %% [markdown]
# ### 8. Data Splitting

# %%
# Split your data to train and test. Choose Splitting ratio wisely.
from sklearn.model_selection import train_test_split

# Splitting dataset into train and test sets

X_train, X_test, y_train, y_test = train_test_split(
    X_scaled,
    y,
    test_size=0.2,
    random_state=42
)

print("Training Data Shape:", X_train.shape)
print("Testing Data Shape:", X_test.shape)

# %% [markdown]
# ##### What data splitting ratio have you used and why?

# %% [markdown]
# An 80:20 train-test split was used to ensure sufficient training data while maintaining a reliable test set for evaluation.

# %% [markdown]
# ### 9. Handling Imbalanced Dataset

# %% [markdown]
# ##### Do you think the dataset is imbalanced? Explain Why.

# %% [markdown]
# No. The dataset is a regression dataset with a continuous target variable, so class imbalance is not applicable.

# %%
# Handling Imbalanced Dataset (If needed)
# Not Applicable for this regression problem

print("Imbalanced Dataset Handling Not Required")

# %% [markdown]
# ##### What technique did you use to handle the imbalance dataset and why? (If needed to be balanced)

# %% [markdown]
# Not required, as imbalance handling techniques are mainly used in classification problems.

# %% [markdown]
# ## ***7. ML Model Implementation***

# %% [markdown]
# ### ML Model - 1

# %%
# ML Model - 1 Implementation

# Fit the Algorithm
from sklearn.linear_model import LinearRegression

# Create and train model

lr = LinearRegression()

lr.fit(X_train, y_train)

# Predicting target values

y_pred_lr = lr.predict(X_test)

# First 5 predictions

print(y_pred_lr[:5])

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

# Calculate metrics

mae_lr = mean_absolute_error(y_test, y_pred_lr)
mse_lr = mean_squared_error(y_test, y_pred_lr)
rmse_lr = np.sqrt(mse_lr)
r2_lr = r2_score(y_test, y_pred_lr)

print("MAE :", mae_lr)
print("MSE :", mse_lr)
print("RMSE :", rmse_lr)
print("R2 Score :", r2_lr)

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
metrics = ['MAE', 'RMSE', 'R2 Score']
scores = [mae_lr, rmse_lr, r2_lr]

plt.figure(figsize=(8,5))
sns.barplot(x=metrics, y=scores)

plt.title('Linear Regression Evaluation Metrics')
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

# Create Model
lr = LinearRegression()

# Hyperparameter Grid
param_grid = {
    'fit_intercept': [True, False],
    'positive': [True, False]
}

# Grid Search CV
grid_search = GridSearchCV(
    estimator=lr,
    param_grid=param_grid,
    cv=5,
    scoring='r2'
)

# Fit Grid Search
grid_search.fit(X_train, y_train)

# Best Parameters
print("Best Parameters:", grid_search.best_params_)
print("Best Cross Validation Score:", grid_search.best_score_)

# Fit the Algorithm
# Best Linear Regression Model

best_lr = grid_search.best_estimator_

# Train Model

best_lr.fit(X_train, y_train)

# Predict on the model
# Predict using tuned model

y_pred_best_lr = best_lr.predict(X_test)

# First 5 Predictions

print(y_pred_best_lr[:5])

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# GridSearchCV was used for hyperparameter optimization. It systematically tests different combinations of hyperparameters using cross-validation and selects the combination that gives the best model performance. This helps improve model accuracy and generalization.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, a slight improvement was observed after applying GridSearchCV. The optimized model achieved better generalization and maintained strong prediction performance on unseen data. The R² Score improved slightly, while MAE and RMSE were reduced, indicating more accurate predictions.

# %% [markdown]
# ### ML Model - 2

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# Evaluation Metric Score Chart

metrics = ['MAE', 'RMSE', 'R2 Score']
scores = [mae_lr, rmse_lr, r2_lr]

plt.figure(figsize=(8,5))
plt.bar(metrics, scores)

plt.title('Linear Regression Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 1 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
from sklearn.model_selection import GridSearchCV
from sklearn.linear_model import LinearRegression

# Create Model
lr = LinearRegression()

# Hyperparameter Grid
param_grid = {
    'fit_intercept': [True, False],
    'positive': [True, False]
}

# Grid Search CV
grid_search = GridSearchCV(
    estimator=lr,
    param_grid=param_grid,
    cv=5,
    scoring='r2'
)

grid_search.fit(X_train, y_train)

# Best Parameters
print("Best Parameters:", grid_search.best_params_)

# Fit the Algorithm
# Best Model

best_lr = grid_search.best_estimator_

# Train Model

best_lr.fit(X_train, y_train)

# Predict on the model
# Prediction

y_pred_best_lr = best_lr.predict(X_test)

print(y_pred_best_lr[:5])

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# GridSearchCV was used for hyperparameter optimization because it systematically evaluates different hyperparameter combinations using cross-validation and selects the best-performing model configuration.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, after applying GridSearchCV, the model showed slightly better performance. The R² Score improved while MAE and RMSE decreased, indicating more accurate and reliable predictions.

# %% [markdown]
# #### 3. Explain each evaluation metric's indication towards business and the business impact pf the ML model used.

# %% [markdown]
# MAE (Mean Absolute Error)
#
# MAE measures the average prediction error. A lower MAE indicates that the predicted stock prices are closer to the actual prices, helping investors make more accurate decisions.
#
# RMSE (Root Mean Squared Error)
#
# RMSE gives higher importance to large prediction errors. A lower RMSE indicates better model reliability and reduces the risk of significant forecasting mistakes in financial planning.
#
# R² Score (Coefficient of Determination)
#
# R² Score measures how well the model explains the variation in stock prices. A higher R² Score indicates that the model captures stock price behavior effectively, improving confidence in predictions.
#
# Business Impact
#
# Accurate stock price predictions can help investors, analysts, and financial institutions make informed investment decisions, reduce uncertainty, and improve overall financial planning and risk management.

# %% [markdown]
# ### ML Model - 3

# %%
# ML Model - 3 Implementation

# Fit the Algorithm
from sklearn.ensemble import RandomForestRegressor

# Create Model

rf = RandomForestRegressor(
    n_estimators=100,
    random_state=42
)

# Train Model

rf.fit(X_train, y_train)

# Predict on the model
# Prediction

y_pred_rf = rf.predict(X_test)

print(y_pred_rf[:5])

# %% [markdown]
# #### 1. Explain the ML Model used and it's performance using Evaluation metric Score Chart.

# %%
# Visualizing evaluation Metric Score chart
# Calculate Evaluation Metrics

from sklearn.metrics import mean_absolute_error, mean_squared_error, r2_score
import numpy as np

mae_rf = mean_absolute_error(y_test, y_pred_rf)
rmse_rf = np.sqrt(mean_squared_error(y_test, y_pred_rf))
r2_rf = r2_score(y_test, y_pred_rf)

# Visualizing Evaluation Metric Score Chart

metrics = ['MAE', 'RMSE', 'R2 Score']
scores = [mae_rf, rmse_rf, r2_rf]

plt.figure(figsize=(8,5))
plt.bar(metrics, scores)

plt.title('Random Forest Evaluation Metrics')
plt.xlabel('Metrics')
plt.ylabel('Score')
plt.show()

# %% [markdown]
# #### 2. Cross- Validation & Hyperparameter Tuning

# %%
# ML Model - 3 Implementation with hyperparameter optimization techniques (i.e., GridSearch CV, RandomSearch CV, Bayesian Optimization etc.)
from sklearn.model_selection import GridSearchCV
from sklearn.ensemble import RandomForestRegressor

# Parameter Grid

param_grid = {
    'n_estimators': [100, 200],
    'max_depth': [5, 10, None],
    'min_samples_split': [2, 5]
}

# Grid Search

grid_search_rf = GridSearchCV(
    RandomForestRegressor(random_state=42),
    param_grid,
    cv=5,
    scoring='r2'
)

grid_search_rf.fit(X_train, y_train)

print("Best Parameters:", grid_search_rf.best_params_)

# Fit the Algorithm
# Best Random Forest Model

best_rf = grid_search_rf.best_estimator_

# Train Model

best_rf.fit(X_train, y_train)

# Predict on the model

y_pred_best_rf = best_rf.predict(X_test)

print(y_pred_best_rf[:5])

# %% [markdown]
# ##### Which hyperparameter optimization technique have you used and why?

# %% [markdown]
# GridSearchCV was used for hyperparameter optimization because it systematically evaluates multiple parameter combinations using cross-validation and selects the best-performing model.

# %% [markdown]
# ##### Have you seen any improvement? Note down the improvement with updates Evaluation metric Score Chart.

# %% [markdown]
# Yes, the tuned model showed improved performance. MAE and RMSE decreased slightly, while the R² Score increased, indicating better prediction accuracy and generalization.

# %% [markdown]
# ### 1. Which Evaluation metrics did you consider for a positive business impact and why?

# %% [markdown]
# MAE, RMSE, and R² Score were used to evaluate model performance.
#
# MAE measures the average prediction error and helps assess prediction accuracy.
# RMSE penalizes larger errors and helps identify significant forecasting mistakes.
# R² Score measures how well the model explains variations in stock prices.
#
# These metrics ensure that the model provides reliable predictions for investment and financial decision-making.

# %% [markdown]
# ### 2. Which ML model did you choose from the above created models as your final prediction model and why?

# %% [markdown]
# Random Forest Regressor was selected as the final model because it achieved the highest R² Score and the lowest prediction errors (MAE and RMSE) compared to the other models. It effectively captured complex relationships in the stock price data and provided more accurate predictions.

# %% [markdown]
# ### 3. Explain the model which you have used and the feature importance using any model explainability tool?

# %% [markdown]
# Random Forest Regressor is an ensemble learning algorithm that combines multiple decision trees to improve prediction accuracy and reduce overfitting.
#
# Feature importance analysis showed that Open Price, High Price, and Low Price were the most influential features in predicting the Closing Price. Among these, the feature with the highest importance contributed the most to the model's predictions. This explainability helps stakeholders understand which stock price indicators have the greatest impact on forecasting future closing prices.

# %%
# Feature Importance

feature_importance = pd.DataFrame({
    'Feature': X.columns,
    'Importance': best_rf.feature_importances_
})

feature_importance = feature_importance.sort_values(
    by='Importance',
    ascending=False
)

plt.figure(figsize=(8,5))
sns.barplot(
    x='Importance',
    y='Feature',
    data=feature_importance
)

plt.title('Feature Importance - Random Forest')
plt.show()

# %% [markdown]
# ## ***8.*** ***Future Work (Optional)***

# %% [markdown]
# ### 1. Save the best performing ml model in a pickle file or joblib file format for deployment process.

# %%
# Save the File
# Save the trained model

import pickle

with open('yes_bank_stock_prediction_model.pkl', 'wb') as file:
    pickle.dump(best_rf, file)

print("Model saved successfully!")

# %% [markdown]
# ### 2. Again Load the saved model file and try to predict unseen data for a sanity check.

# %%
# Load the File and predict unseen data.
# Load Saved Model

import pickle

with open('yes_bank_stock_prediction_model.pkl', 'rb') as file:
    loaded_model = pickle.load(file)

# Predict on unseen data

y_pred_unseen = loaded_model.predict(X_test)

print("First 5 Predictions:")
print(y_pred_unseen[:5])

# %% [markdown]
# ### ***Congrats! Your model is successfully created and ready for deployment on a live server for a real user interaction !!!***

# %% [markdown]
# # **Conclusion**

# %% [markdown]
# In this project, historical stock price data of Yes Bank was analyzed and used to build machine learning models for predicting the closing stock price. Data preprocessing, exploratory data analysis, feature engineering, and model evaluation were performed to identify important patterns and relationships in the dataset. Multiple regression models were trained and compared using evaluation metrics such as MAE, RMSE, and R² Score.
#
# Among all the models, the Random Forest Regressor achieved the best performance and was selected as the final model. The results demonstrated that Open, High, and Low prices are strong predictors of the Closing Price. This project highlights how machine learning can be effectively applied to financial data to generate reliable stock price predictions and support data-driven investment decisions.

# %% [markdown]
# ### ***Hurrah! You have successfully completed your Machine Learning Capstone Project !!!***
